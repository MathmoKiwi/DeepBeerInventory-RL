# %%
tensorflow_version 1.15.0
# Out:
#   Input In [7]
#     tensorflow_version 1.15.0
#                        ^
# SyntaxError: invalid syntax

# %%
# !pip install numpyencoder
import numpyencoder
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)

# %%
# !pip install numpy
import numpy
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py:58, in <module>
#      56   sys.setdlopenflags(_default_dlopen_flags | ctypes.RTLD_LOCAL)
# ---> 58 from tensorflow.python.pywrap_tensorflow_internal import *
#      59 from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:28, in <module>
#      27         return _mod
# ---> 28 _pywrap_tensorflow_internal = swig_import_helper()
#      29 del swig_import_helper
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:24, in swig_import_helper()
#      23 try:
# ---> 24     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25 finally:
#
# ...

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 print("TensorFlow version:", tf.__version__)
#
# NameError: name 'tf' is not defined

# %%
pip install http://storage.googleapis.com/tensorflow-serving-apt/pool/tensorflow-model-server-1.15.0/t/tensorflow-model-server/tensorflow-model-server_1.15.0_all.deb
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.6/142.6 MB 11.8 MB/s eta 0:00:0000:0100:01
#   ERROR: Cannot unpack file /tmp/pip-unpack-7uvr9ab8/tensorflow-model-server_1.15.0_all.deb (downloaded from /tmp/pip-req-build-2ymrg6sx, content-type: application/x-debian-package); cannot detect archive format
# ERROR: Cannot determine archive format of /tmp/pip-req-build-2ymrg6sx
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==1.15.0
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.15.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for tensorflow==1.15.0
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 "main.py"
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "/opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "/opt/conda/lib/python3.10/site-packages/tensorflow/python/pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "/opt/conda/lib/python3.10/imp.py", line 243, in load_module
#     return load_dynamic(name, filename, file)
#   File "/opt/conda/lib/python3.10/imp.py", line 343, in load_dynamic
#     return _load(spec)
# ImportError: /opt/conda/lib/python3.10/site-packages/tensorflow/python/_pywrap_tensorflow_internal.so: invalid ELF header
#
# ...

# %%
pip install /mnt/tensorflow-1.12.0rc0-cp310-cp310-manylinux_2_31_x86_64.whl
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Requirement '/mnt/tensorflow-1.12.0rc0-cp310-cp310-manylinux_2_31_x86_64.whl' looks like a filename, but the file does not exist
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# Processing /mnt/tensorflow-1.12.0rc0-cp310-cp310-manylinux_2_31_x86_64.whl
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/mnt/tensorflow-1.12.0rc0-cp310-cp310-manylinux_2_31_x86_64.whl'
#
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
#You must be using python <=3.7 to install Tensorflow 1.15 (currently on 3.10)
pip uninstall tensorflow  # remove current version
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.10/site-packages)
# Found existing installation: tensorflow 1.5.0
# Uninstalling tensorflow-1.5.0:
#   Would remove:
#     /opt/conda/bin/freeze_graph
#     /opt/conda/bin/saved_model_cli
#     /opt/conda/bin/tensorboard
#     /opt/conda/bin/toco
#     /opt/conda/bin/toco_from_protos
#     /opt/conda/lib/python3.10/site-packages/external/*
#     /opt/conda/lib/python3.10/site-packages/tensorflow-1.5.0.dist-info/*
#     /opt/conda/lib/python3.10/site-packages/tensorflow/*
#   Would not remove (might be manually added):
#     /opt/conda/lib/python3.10/site-packages/tensorflow/_api/__init__.py
#     /opt/conda/lib/python3.10/site-packages/tensorflow/_api/v2/__init__.py
#     /opt/conda/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py
# ...
